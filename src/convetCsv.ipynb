# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style='white', context='notebook', palette='Set2')

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_1 = pd.read_csv("../data/1901-1902.csv")
df_2 = pd.read_csv("../data/1903-1904.csv")
df_3 = pd.read_csv("../data/1905-1906.csv")
df_4 = pd.read_csv("../data/1907-1908.csv")
df_5 = pd.read_csv("../data/1909-1910.csv")
df_6 = pd.read_csv("../data/1911-1912.csv")
df_7 = pd.read_csv("../data/1913-1914.csv")
df_8 = pd.read_csv("../data/1915-1916.csv")
df_9 = pd.read_csv("../data/1917-1918.csv")
df_10 = pd.read_csv("../data/1919-1920.csv")

dataset = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10])

# %%
# dataset = pd.read_csv("../dataset/online-data/dataset.csv")
dataset = dataset.drop(columns=["Unnamed: 0"])
dataset = dataset.replace( 'Series\(\[\], Name: location, dtype: int64\)', '', regex=True)
dataset = dataset.replace('', np.nan)
dataset = dataset.dropna(subset=['out2'])

# %%
dataset = dataset.replace( '\n', ':', regex=True)
# dataset = dataset.replace( '..', '', regex=True)
dataset = dataset.replace( '\r', '', regex=True)

# %%
dataset = dataset.replace({'Edinburgh': 'EDI', 'Liverpool': 'LVP', 'London': 'LON', 'Marseilles': 'MAR', 'Paris': 'PAR', 'Brest': 'BRE',
       'Venice': 'VEN', 'Rome': 'ROM', 'Naples': 'NAP', 'Munich': 'MUN', 'Berlin': 'BER', 'Kiel': 'KIE', 'Vienna': 'VIE',
       'Trieste': 'TRI', 'Budapest': 'BUD', 'Constantinople': 'CON', 'Ankara': 'ANK', 'Smyrna': 'SMY',
       'Moscow': 'MOS', 'St. Petersburg \(South Coast\) ': 'STP', 'Warsaw': 'WAR', 'Sevastopol': 'SEV',
       'Norwegian Sea': 'NWG', 'Yorkshire': 'YOR', 'North Sea': 'NTH', 'Picardy': 'PIC',
       'Mid-Atlantic Ocean': 'MAO', 'Tyrrhenian Sea': 'TYS', 'Silesia': 'SIL', 'Holland': 'HOL',
       'Albania': 'ALB', 'Serbia': 'SER','Gulf of Bothnia': 'GOB', 'Ukraine': 'UKR', 'Norway': 'NWY', 'Belgium': 'BEL', 'Portugal': 'POR',
       'Piedmont': 'PIA', 'Tunis': 'TUN', 'Galicia': 'GAL', 'Greece': 'GRE', 'Black Sea': 'BLA', 'Finland': 'FIN',
       'Sweden': 'SWE', 'Rumania': 'RUM', 'Helgoland Bight': 'HEL', 'Burgundy': 'BUR',
       'English Channel': 'ENC', 'Tyrolia': 'TYR', 'Ionian Sea': 'ION', 'Denmark': 'DEN', 'Wales': 'WAL',
       'Irish Sea': 'IRI', 'Armenia': 'ARM', 'St. Petersburg \(North Coast\)': 'STP',
       'North Atlantic Ocean': 'NAO', 'Ruhr': 'RUH', 'Aegean Sea': 'AEG', 'Apulia': 'APU',
       'Skagerrack': 'SKA', 'nan': 'NAN', 'Gascony': 'GAS', 'Prussia': 'PRU', 'Barents Sea': 'BAR', 'Bohemia': 'BOH',
       'Adriatic Sea': 'ADR', 'Western Mediterranean': 'WMS', 'Tuscany': 'TUS', 'Baltic Sea': 'BAL',
       'Gulf of Lyons': 'GOL', 'Eastern Mediterranean': 'EMS', 'Spain \(North Coast\)': 'SPA', 
       'Syria': 'SYR', 'Livonia': 'LIV', 'Clyde': 'CLY', 'Spain \(South Coast\)': 'SPA', 'North Africa': 'NAF',
       'Bulgaria \(South Coast\)': 'BUL', 'Bulgaria \(East Coast\)':'BUL'}, regex=True)
dataset = dataset.replace({'Bulgaria': 'BUL', 'Spain': 'SPA', 'St. Petersburg': 'STP'}, regex=True)

# %%
dataset = dataset.replace( ' ', '', regex=True)
dataset = dataset.replace( '\.\.', '', regex=True)

# %%
dataset
# Out:
#                 in                                               out1  \
# 0     1901SpringE0                            EDI3556:LVP3491:LON3371
# 98    1901SpringF0                            PAR3730:MAR3658:BRE3590
# 196   1901SpringI0                            NAP2417:ROM2272:VEN2118
# 294   1901SpringG0                            KIE4129:BER3996:MUN3545
# 392   1901SpringA0                            BUD3501:TRI3310:VIE2844
# 490   1901SpringT0                            CON5368:SMY5219:ANK3235
# 588   1901SpringR0                    STP4950:MOS4923:WAR4311:SEV2546
# 686     1901FallE0  NTH3132:NWG2226:YOR1685:EDI1000:ENC879:WAL398:...
# 693     1901FallE8                                                NaN
# 784     1901FallF0  MAO2794:SPA2173:BUR1466:PIC1306:MAR1137:GAS427...
# 791     1901FallF8                                               BUR1
# 882     1901FallI0  ION1951:VEN1604:APU735:TYR469:NAP409:PIA328:TY...
# 889     1901FallI8                                               VEN1
# 980     1901FallG0  KIE3433:RUH2099:DEN1353:HOL1065:MUN860:BUR253:...
# 987     1901FallG8                                                NaN
# 1078    1901FallA0  SER2446:ALB2403:TRI1262:BUD908:VIE579:GAL539:R...
# 1085    1901FallA8                                               RUM3
# 1176    1901FallT0  BUL3547:CON2973:ANK2084:BLA1555:ARM619:SMY532:...
# 1183    1901FallT8                                                NaN
# 1274    1901FallR0  GOB4145:UKR3553:SEV2254:GAL1546:WAR1377:RUM122...
# 1281    1901FallR8                                     RUM8:WAR1:SEV1
# 1372  1902SpringE0  LON2479:NWY2408:NTH2237:EDI1611:BEL786:LVP625:...
# 1379  1902SpringE8  LON137:NWY116:EDI104:NTH98:BEL40:DEN37:NWG37:E...
# 1470  1902SpringF0  POR2675:PAR2476:MAR2316:BRE2300:SPA2266:BEL136...
# 1477  1902SpringF8  POR188:PAR187:BRE178:MAR151:SPA150:BEL92:BUR46...
# 1568  1902SpringI0  NAP1563:TUN1525:VEN1440:ION827:ROM660:TRI429:T...
# 1575  1902SpringI8  NAP176:TUN152:VEN148:ION94:TRI67:ROM60:TYR36:A...
# 1666  1902SpringG0  KIE2994:MUN2727:HOL2707:BER2524:DEN2211:BEL101...
# 1673  1902SpringG8  KIE172:BER156:HOL143:MUN138:DEN131:BEL71:RUH60...
# 1764  1902SpringA0  BUD2458:TRI2343:SER2335:VIE2294:GRE1701:RUM555...
# ...            ...                                                ...
# 2660   1920FallR80                                                NaN
# 2661   1920FallR12       GOL1WAR1BAR1BER1SIL1PRU1GAS1MAR1BOH1MOS1MUN1
# 2665  1920FallR116                                                NaN
# 2666   1920FallR68                                                NaN
# 2667   1920FallR84                                                NaN
# 2668   1920FallR36                                                NaN
# 2669   1920FallR56  MUN2DEN2SEV2KIE2NWY1BAL1IRI1SWE1UKR1BER1LON1VI...
# 2670   1920FallR40                                               MUN1
# 2671   1920FallR20                                                NaN
# 2673   1920FallR24  MUN2SIL2GAL2DEN1BLA1KIE1ARM1ANK1NWY1BRE1BUL1VI...
# 2675   1920FallR44  SIL2NWY2TYR1WAR1BER1PRU1ENC1LIV1BEL1NAO1FIN1BA...
# 2677   1920FallR34                                                NaN
# 2679   1920FallR18                                                NaN
# 2681   1920FallR35                                                NaN
# 2683   1920FallR66                                                NaN
# 2686   1920FallR96                                                NaN
# 2688   1920FallR65                                                NaN
# 2691  1920FallR108                               GOB1LIV1BER1SIL1FIN1
# 2692  1920FallR104                   ION1TYR1WAR1UKR1GAL1RUM1AEG1APU1
# 2694   1920FallR28  RUM2TRI1BUL1SER1ENC1NTH1BLA1MOS1VIE1SIL1GAL1AN...
# 2695   1920FallR97                                                NaN
# 2696   1920FallR33                                                NaN
# 2700   1920FallR26                                                NaN
# 2703   1920FallR48                                                NaN
# 2704   1920FallR14                                                NaN
# 2705   1920FallR76   BER2RUM1BAR1UKR1PRU1ALB1NWY1SWE1BAL1ROM1FIN1MUN1
# 2716   1920FallR73                                                NaN
# 2722   1920FallR25                                                NaN
# 2731   1920FallR60                       WAR1SWE1LIV1KIE1BAL1STP1MUN1
# 2737   1920FallR77                                                NaN
#
#                                                    out2
# 0                            EDI24689:LVP24015:LON22896
# 98                           MAR24595:PAR24037:BRE23145
# 196                          NAP24629:ROM22885:VEN22376
# 294                          KIE25787:BER24326:MUN22445
# 392                          BUD23956:TRI23018:VIE19703
# 490                          CON25695:SMY24653:ANK14744
# 588                 STP24342:MOS24302:WAR21149:SEV13631
# 686   NTH19995:NWG13846:YOR10898:EDI6734:ENC5384:LON...
# 693                                      NTH5:NWG3:CLY1
# 784   MAO17296:SPA15028:BUR7725:PIC7640:MAR6816:BRE3...
# 791        MAO7:BUR3:MAR3:BRE1:ENC1:PAR1:PIA1:SPA1:PIC1
# 882   ION17720:VEN15679:APU6050:NAP5905:ROM4867:TYS4...
# 889               VEN40:TRI17:ION14:PIA5:NAP4:APU2:TYR1
# 980   KIE18601:RUH11106:DEN8262:HOL7338:MUN6946:BER3...
# 987            RUH23:MUN8:DEN2:KIE1:BAL1:PRU1:TYR1:HOL1
# 1078  SER14373:ALB12333:TRI10554:BUD7230:VIE6109:GAL...
# 1085  RUM127:ALB127:TRI92:SER31:ADR29:GAL22:VIE13:BU...
# 1176  BUL14545:CON12759:ANK10965:BLA5418:SMY3850:ARM...
# 1183                                              BUL12
# 1274  GOB17178:UKR14714:SEV10842:WAR9787:RUM6139:GAL...
# 1281                               RUM44:SEV4:GAL2:WAR1
# 1372  NTH14009:LON13573:NWY13546:EDI9054:YOR4827:LVP...
# 1379  NTH1255:LON975:NWY910:EDI726:ENC459:YOR443:LVP...
# 1470  POR14864:SPA14201:PAR14055:MAR13637:BRE12700:B...
# 1477  SPA1168:POR1167:PAR1125:MAR1087:BRE1083:BUR499...
# 1568  TUN14594:VEN14161:NAP14022:ION7951:ROM6840:TYR...
# 1575  VEN1269:TUN1167:NAP1102:ION722:ROM587:TYR296:T...
# 1666  KIE15934:HOL14462:MUN14180:BER13432:DEN11387:R...
# 1673  KIE1356:MUN1223:HOL1105:BER1070:DEN940:RUH449:...
# 1764  BUD13572:TRI13341:SER13170:VIE12635:GRE6581:AL...
# ...                                                 ...
# 2660                                   WAR1LIV1SIL1AEG1
# 2661  MOS4MUN3KIE3LIV3BER3NWY2GAL2NWG2SIL2WAR2GAS2NA...
# 2665                                               UKR1
# 2666                               WAR2RUM1UKR1MOS1BER1
# 2667                                   MOS2RUM1LIV1BER1
# 2668                                       LIV1BAL1STP1
# 2669  SWE3MUN2BAL2DEN2LON2KIE2SEV2NWY2PRU2VIE2NTH2HO...
# 2670   RUM1SKA1UKR1GAL1SER1BER1NWY1ALB1MOS1VIE1DEN1MUN1
# 2671                               BAR1SKA1BAL1DEN1NWY1
# 2673  GAL3MUN2ARM2BEL2NWY2SIL2RUH1DEN1BLA1KIE1SER1AN...
# 2675  MOS3WAR2NWG2LIV2NWY2SIL2TRI1RUH1STP1SKA1IRI1FI...
# 2677                                               BUL1
# 2679                               LIV1NAO1IRI1STP1PRU1
# 2681                                               CON1
# 2683                                               SEV1
# 2686                                               ARM2
# 2688                           MOS2WAR1SIL1GOB1STP1TUN1
# 2691               SIL2BER1RUH1GAL1GAS1LIV1GOB1FIN1MUN1
# 2692  RUM2WAR1ION1GAL1BER1VIE1BOH1BLA1TYR1SIL1MUN1AN...
# 2694  RUM2TRI1BUL1SER1ENC1NTH1BLA1MOS1VIE1SIL1GAL1AN...
# 2695                                       WAR1BER1ARM1
# 2696                           LIV1LVP1STP1GOB1FIN1PRU1
# 2700                                   RUM1SEV1GAL1BUD1
# 2703                                               STP1
# 2704       RUM1WAR1NTH1BUD1NWY1NWG1LIV1YOR1VIE1SEV1FIN1
# 2705  BER3MUN2PRU2SIL1MOS1BAL1LIV1SWE1NWY1WAR1BAR1UK...
# 2716  MOS3BER2PRU2TYS2LIV2ION1STP1DEN1FIN1SEV1SWE1UK...
# 2722                       RUH1BER1SWE1NWG1KIE1HEL1MUN1
# 2731                       WAR1SWE1LIV1KIE1BAL1STP1MUN1
# 2737                           BER1WAR1UKR1MOS1SIL1ARM1
#
# [19059 rows x 3 columns]

# %%
dataset.to_csv("location.csv")
