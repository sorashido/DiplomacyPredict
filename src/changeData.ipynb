# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style='white', context='notebook', palette='Set2')

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("../dataset/online-data/dataset.csv")
dataset = dataset.drop(columns=["Unnamed: 0"])

# %%
dataset = dataset.replace( '\n', '', regex=True)
dataset = dataset.replace( '\r', ',', regex=True)
dataset = dataset.replace( 'Name: target, dtype: int64', '', regex=True)

# %%
dataset.replace({'Edinburgh': 'EDI', 'Liverpool': 'LVP', 'London': 'LON', 'Marseilles': 'MAR', 'Paris': 'PAR', 'Brest': 'BRE',
       'Venice': 'VEN', 'Rome': 'ROM', 'Naples': 'NAP', 'Munich': 'MUN', 'Berlin': 'BER', 'Kiel': 'KIE', 'Vienna': 'VIE',
       'Trieste': 'TRI', 'Budapest': 'BUD', 'Constantinople': 'CON', 'Ankara': 'ANK', 'Smyrna': 'SMY',
       'Moscow': 'MOS', 'St. Petersburg (South Coast)': '', 'Warsaw': 'WAR', 'Sevastopol': 'SEV',
       'Norwegian Sea': 'NWG', 'Yorkshire': 'YOR', 'North Sea': 'NTH', 'Spain': 'SPA', 'Picardy': 'PIC',
       'Mid-Atlantic Ocean': 'MAO', 'Tyrrhenian Sea': 'TYS', 'Silesia': 'SIL', 'Holland': 'HOL',
       'Albania': 'ALB', 'Serbia': 'SER', 'Bulgaria': 'BUL', 'St. Petersburg': 'STP',
       'Gulf of Bothnia': 'GOB', 'Ukraine': 'UKR', 'Norway': 'NWY', 'Belgium': 'BEL', 'Portugal': 'POR',
       'Piedmont': 'PIA', 'Tunis': 'TUN', 'Galicia': 'GAL', 'Greece': 'GRE', 'Black Sea': 'BLA', 'Finland': 'FIN',
       'Sweden': 'SWE', 'Rumania': 'RUM', 'Helgoland Bight': 'HEL', 'Burgundy': 'BUR',
       'English Channel': 'ENC', 'Tyrolia': 'TYR', 'Ionian Sea': 'IOS', 'Denmark': 'DEN', 'Wales': 'WAL',
       'Irish Sea': 'IRS', 'Armenia': 'ARM', 'St. Petersburg (North Coast)': 'STPNC',
       'North Atlantic Ocean': 'NAO', 'Ruhr': 'RUH', 'Aegean Sea': 'AES', 'Apulia': 'APU',
       'Skagerrack': 'SKA', 'nan': 'NAN', 'Gascony': 'GAS', 'Prussia': 'PRU', 'Barents Sea': 'BAR', 'Bohemia': 'BOH',
       'Adriatic Sea': 'ADS', 'Western Mediterranean': 'WMS', 'Tuscany': 'TUS', 'Baltic Sea': 'BAL',
       'Gulf of Lyons': 'GOL', 'Eastern Mediterranean': 'EMS', 'Spain (North Coast)': 'SPNC',
       'Syria': 'SYR', 'Livonia': 'LIV', 'Clyde': 'CLY', 'Spain (South Coast)': 'SPSC', 'North Africa': 'NAF',
       'Bulgaria (South Coast)': 'BUSC', 'Bulgaria (East Coast)':'BUEC'}, regex=True)
# Out:
#               in                                               out1  \
# 0    1901SpringE  NTH          3448,NWG      2271,YOR          1...
# 1    1901SpringF  MAO    2849,SPA                 2307,BUR      ...
# 2    1901SpringI  IOS        2084,VEN             803,APU       ...
# 3    1901SpringG  KIE               3599,DEN            2704,RUH...
# 4    1901SpringA  SER          3031,ALB         2626,BUD        ...
# 5    1901SpringT  BUL          5311,CON    3990,BLA         2115...
# 6    1901SpringR  GOB    4690,UKR            4074,GAL           ...
# 7      1901FallE  NWY                  3050,fleet LON           ...
# 8      1901FallF  POR                 3008,army PAR             ...
# 9      1901FallI  TUN                    1776,fleet NAP         ...
# 10     1901FallG  army MUN        2584,HOL            2515,fleet...
# 11     1901FallA  army BUD     2553,GRE            2390,army VIE...
# 12     1901FallT  fleet SMY              3120,BUL               ...
# 13     1901FallR  SWE                                4082,RUM   ...
# 14   1902SpringE  NTH                       1608,ENC            ...
# 15   1902SpringF  MAO       2248,BUR                 1879,PIC   ...
# 16   1902SpringI  IOS                1284,TYS             716,VE...
# 17   1902SpringG  KIE                            1454,RUH       ...
# 18   1902SpringA  SER                    1703,GAL               ...
# 19   1902SpringT  BUL                  3236,AES                2...
# 20   1902SpringR  RUM                         2545,GAL          ...
# 21     1902FallE  NWY                          1258,fleet LON   ...
# 22     1902FallF  BUR                 1354,BEL                  ...
# 23     1902FallI  fleet NAP              1032,TUN               ...
# 24     1902FallG  army BER                     1362,BEL         ...
# 25     1902FallA  army VIE               1510,RUM               ...
# 26     1902FallT  BUL                     2492,fleet SMY        ...
# 27     1902FallR  RUM                               2703,army WA...
# 28   1903SpringE  NTH                       1405,NWY            ...
# 29   1903SpringF  BUR                        1639,BEL           ...
# ..           ...                                                ...
# 264    1919FallT  IOS               70,TYS           68,WAR     ...
# 265    1919FallR  MUN                                17,NWY     ...
# 266  1920SpringE  MUN                          33,LON           ...
# 267  1920SpringF  MAO              13,IOS                      1...
# 268  1920SpringI  VEN                   6,TRI                  4...
# 269  1920SpringG  MOS                   33,TYR                  ...
# 270  1920SpringA  TYR                  10,PIA                 10...
# 271  1920SpringT  TYS           36,TUS                  35,VIE  ...
# 272  1920SpringR  MUN                          9,NWY            ...
# 273    1920FallE  MAO              58,ENC                 40,MUN...
# 274    1920FallF  MUN                          11,KIE           ...
# 275    1920FallI  MUN                   7,PIA                 6,...
# 276    1920FallG  TYR                  35,BUD                 33...
# 277    1920FallA  MUN                   9,IOS               8,WA...
# 278    1920FallT  GAL                  24,ROM                   ...
# 279    1920FallR  MUN                                12,BER     ...
# 280  1921SpringE  WMS           53,MAR                      50,M...
# 281  1921SpringF  MAO              9,RUH                        ...
# 282  1921SpringI  TYS           6,MUN                   5,RUM   ...
# 283  1921SpringG  TYR                  37,BUD                 32...
# 284  1921SpringA  WAR                    9,MUN                  ...
# 285  1921SpringT  WAR                          24,PIA           ...
# 286  1921SpringR  BER                   8,MUN                   ...
# 287    1921FallE  TUN                           39,PIA          ...
# 288    1921FallF  army PAR                      8,MUN           ...
# 289    1921FallI  WMS    6,MAR               5,MAO       5,VEN  ...
# 290    1921FallG  BUD                 34,TYR                  20...
# 291    1921FallA  TYS           7,TYR                  7,GAL    ...
# 292    1921FallT  TYS           19,PRU                  17,WAR  ...
# 293    1921FallR  MUN                                8,GAL      ...
#
#                                                   out2
# 0    NTH          23295,NWG      14481,YOR         ...
# 1    MAO    17869,SPA                 16283,BUR    ...
# 2    IOS        18967,APU             7004,VEN     ...
# 3    KIE               19917,DEN            14190,R...
# 4    SER          18986,ALB         14462,BUD      ...
# 5    BUL          24773,CON    18643,BLA          7...
# 6    GOB                 22190,UKR                 ...
# 7    NWY                  18315,YOR               1...
# 8    POR                 17374,army PAR            ...
# 9    TUN                    16970,fleet NAP        ...
# 10   HOL               12442,army MUN           118...
# 11   army BUD     12598,GRE            10708,army V...
# 12   fleet SMY              13389,BUL              ...
# 13   SWE                                15497,RUM  ...
# 14   NTH                       8490,NWY            ...
# 15   MAO       11981,BUR                  9364,PIC ...
# 16   IOS                9342,TYS            7294,VE...
# 17   RUH                            7894,KIE       ...
# 18   SER                    7006,BUD               ...
# 19   BUL                  11296,AES                ...
# 20   RUM                         8731,GAL          ...
# 21   NWY                          6572,fleet LON   ...
# 22   BUR                 7244,BEL                  ...
# 23   TUN                     7163,fleet NAP        ...
# 24   BEL                         5437,MUN          ...
# 25   TRI                   5168,SER                ...
# 26   BUL                     9141,fleet SMY        ...
# 27   RUM                               8081,army WA...
# 28   NTH                       6910,NWY            ...
# 29   BUR                        7988,MAO           ...
# ..                                                 ...
# 264  IOS                      101,TYS              ...
# 265  MUN                                28,MOS     ...
# 266  TUN                           43,MAO          ...
# 267  MAO              28,MAR                      2...
# 268  TYS           13,VEN                   13,WMS ...
# 269  MUN                   65,BER                  ...
# 270  TRI                  56,TYS           27,SER  ...
# 271  TUS                         40,TYS            ...
# 272  MUN                          19,NWY           ...
# 273  MAO              73,ENC                 50,MUN...
# 274  MAR                      27,MUN               ...
# 275  PIA                 13,WMS    13,MUN          ...
# 276  MUN                          67,TYR           ...
# 277  TRI                   41,SER                  ...
# 278  IOS                31,GAL                   26...
# 279  MUN                                18,BER     ...
# 280  WMS           58,MAO              52,MAR      ...
# 281  MAO              24,MAR                      1...
# 282  TYS           9,PIA                 9,TYR     ...
# 283  MUN                   65,TYR                  ...
# 284  TRI                   55,VEN                  ...
# 285  WAR                          29,PIA           ...
# 286  MUN                          13,NWY           ...
# 287  GOL                   59,TUN                  ...
# 288  MUN                          19,MAO           ...
# 289  WMS    10,GOL             8,MAR               ...
# 290  MUN                   64,BUD                 3...
# 291  TRI                  39,TUS                  3...
# 292  TYS           27,IOS               25,PRU     ...
# 293  MUN                                16,BER     ...
#
# [294 rows x 3 columns]

# %%
dataset.to_csv("new.csv")
