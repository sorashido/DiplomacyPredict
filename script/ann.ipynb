# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## import dataset

# %%
dataset = pd.read_csv('../dataset/data01.csv')
dataset = dataset.iloc[:, 1:126]

# tX = dataset.iloc[:, 2:124]
# tY = dataset.iloc[:, 125]
# X = dataset.iloc[:, 2:123].values #idや名前は除去(特徴量ではない)
# y = dataset.iloc[:, 125].values #output(0 or 1)

# %%
dataset.head()
# Out:
#    GAME COUNTRY  YEAR NAPFLT GOBFLT SERAMY NWYAMY GASAMY AEGFLT TUNAMY  ...    \
# 0     1     RUS  1901     []     []     []     []     []     []     []  ...
# 1     1     AUS  1901     []     []    AUS     []     []     []     []  ...
# 2     1     GER  1901     []     []    AUS     []     []     []     []  ...
# 3     1     TUR  1901     []     []    AUS     []     []     []     []  ...
# 4     1     FRA  1901     []     []    AUS     []     []     []     []  ...
#
#   MARFLT ROMFLT EDIAMY EDIFLT LONAMY NAPAMY NAOFLT MUNAMY LONFLT OUTPUT
# 0     []     []     []     []     []     []     []     []     []      4
# 1     []     []     []     []     []     []     []     []     []      4
# 2     []     []     []     []     []     []     []     []     []      4
# 3     []     []     []     []     []     []     []     []     []      4
# 4     []     []     []     []     []     []     []    FRA     []      6
#
# [5 rows x 125 columns]

# %% [markdown]
# 国別に分けて, outputのデータを最終年の補給地の数にする

# %%
rus_dataset = dataset[dataset.COUNTRY == 'RUS']
aus_dataset = dataset[dataset.COUNTRY == 'AUS']
ger_dataset = dataset[dataset.COUNTRY == 'GER']
tur_dataset = dataset[dataset.COUNTRY == 'TUR']
fra_dataset = dataset[dataset.COUNTRY == 'FRA']
eng_dataset = dataset[dataset.COUNTRY == 'ENG']
ita_dataset = dataset[dataset.COUNTRY == 'ITA']

# %%
eng_dataset.head()
# Out:
#     GAME COUNTRY  YEAR NAPFLT GOBFLT SERAMY NWYAMY GASAMY AEGFLT TUNAMY  \
# 5      1     ENG  1901     []     []    AUS     []     []     []     []
# 12     1     ENG  1902     []    RUS    AUS     []     []    TUR     []
# 19     1     ENG  1903     []    RUS    AUS     []     []    TUR     []
# 26     1     ENG  1904     []    RUS    AUS     []    FRA    TUR     []
# 33     1     ENG  1905    FRA    RUS    AUS     []    FRA    TUR     []
#
#     ...   MARFLT ROMFLT EDIAMY EDIFLT LONAMY NAPAMY NAOFLT MUNAMY LONFLT  \
# 5   ...       []     []     []     []     []     []     []    FRA     []
# 12  ...       []     []     []     []     []     []     []    FRA     []
# 19  ...       []     []     []     []     []     []     []    FRA     []
# 26  ...       []     []     []     []    ENG     []     []    FRA     []
# 33  ...       []     []     []     []    ENG     []     []    FRA     []
#
#    OUTPUT
# 5       3
# 12      4
# 19      4
# 26      3
# 33      3
#
# [5 rows x 125 columns]

# %%
from sklearn.utils import shuffle

# %%
tX = eng_dataset.iloc[:, 0:124]
tX = shuffle(tX)
tX = tX.drop_duplicates('GAME')
tX = tX.sort_values('GAME').iloc[:, 2:124]
tY = eng_dataset.drop_duplicates('GAME', keep = 'last').iloc[:,124]

# %%
tX.head()
# Out:
#      YEAR NAPFLT GOBFLT SERAMY NWYAMY GASAMY AEGFLT TUNAMY NWYFLT GASFLT  \
# 26   1904     []    RUS    AUS     []    FRA    TUR     []    RUS     []
# 103  1908    ITA    RUS    AUS     []    FRA    AUS     []    ENG     []
# 166  1902    ITA    RUS    AUS    RUS    FRA    TUR     []    ENG     []
# 243  1902    ITA    RUS    AUS    RUS    RUS    TUR     []    ENG     []
# 348  1901    ITA    RUS    AUS    RUS    FRA    TUR     []    ENG    ITA
#
#      ...   GALAMY MARFLT ROMFLT EDIAMY EDIFLT LONAMY NAPAMY NAOFLT MUNAMY  \
# 26   ...      GER     []     []     []     []    ENG     []     []    FRA
# 103  ...      RUS     []     []     []    ENG    ENG     []    ENG    GER
# 166  ...      RUS     []    ITA    ENG    ENG    ENG     []    ENG    GER
# 243  ...      RUS    ITA    ITA    ENG    ENG    ENG    ITA    ENG    GER
# 348  ...      RUS    ITA    ITA    ENG    ENG    ENG    ITA    FRA    ITA
#
#     LONFLT
# 26      []
# 103    ENG
# 166    FRA
# 243    ENG
# 348    ENG
#
# [5 rows x 122 columns]

# %%
tY.head()
# Out:
# 47      3
# 152     4
# 229     5
# 341    10
# 460     4
# Name: OUTPUT, dtype: int64

# %%
print(tX.shape,tY.shape)
# Out:
# (3093, 122) (3093,)

# %%
X = tX.values
y = tY.values

# %% [markdown]
# ## Encoding categorical data
# データの成形を行う

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

##labelをエンコードする
le = LabelEncoder()
le.fit(['RUS','AUS','GER','TUR','FRA','ENG', 'ITA', '[]'])

for i in range(121):
    X[:, i+1] = le.transform(X[:, i+1])

### Gender
# labelencoder_X_2 = LabelEncoder()
# X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

# %%
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()

# %% [markdown]
# ##  データセットと学習セットに分ける

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train.shape)
# Out:
# (2474, 128)

# %% [markdown]
# # モデルの作成

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
# Initialising the ANN
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 128))
# Adding the second hidden layer
model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu'))
# Adding the output layer
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'relu'))

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 2474/2474 [==============================] - 0s - loss: 17.5737 - acc: 0.1221
# Epoch 2/100
# 2474/2474 [==============================] - 0s - loss: 10.1080 - acc: 0.1378
# Epoch 3/100
# 2474/2474 [==============================] - 0s - loss: 9.2488 - acc: 0.1479
# Epoch 4/100
# 2474/2474 [==============================] - 0s - loss: 8.7089 - acc: 0.1435
# Epoch 5/100
# 2474/2474 [==============================] - 0s - loss: 8.0985 - acc: 0.1407
# Epoch 6/100
# 2474/2474 [==============================] - 0s - loss: 7.5777 - acc: 0.1589
# Epoch 7/100
# 2474/2474 [==============================] - 0s - loss: 8.2689 - acc: 0.1702
# Epoch 8/100
# 2474/2474 [==============================] - 0s - loss: 6.8312 - acc: 0.1653
# Epoch 9/100
# 2474/2474 [==============================] - 0s - loss: 6.2014 - acc: 0.1787
# Epoch 10/100
# 2474/2474 [==============================] - 0s - loss: 5.5719 - acc: 0.1876
